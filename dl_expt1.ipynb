# %% [markdown]
# <a href="https://colab.research.google.com/github/Jenoprabakar/DeepLearning-lab-experiments/blob/main/dl_expt1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.linear_model import Perceptron
import matplotlib.pyplot as plt
X = np.array([
    [1, 2],
    [2, 1],
    [2, 4],
    [3, 5],
    [6, 4],
    [7, 2]])
y = np.array([0, 0, 0, 0, 1, 1])
model = Perceptron(
    max_iter=1000,
    eta0=0.1,
    tol=None)
model.fit(X, y)
print("Weights (w):", model.coef_)
print("Bias (b):", model.intercept_)
test_point = np.array([[5, 3]])
prediction = model.predict(test_point)
print("Prediction for [5,3]:", prediction)
plt.scatter(X[:,0], X[:,1], c=y, cmap='bwr')
w1, w2 = model.coef_[0]
b = model.intercept_[0]
x_vals = np.linspace(0, 8, 100)
y_vals = -(w1*x_vals + b) / w2
plt.plot(x_vals, y_vals)
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("Single Unit Perceptron Decision Boundary")
plt.show()
# Out:
# Weights (w): [[ 0.5 -0.6]]
# Bias (b): [-0.5]
# Prediction for [5,3]: [1]
